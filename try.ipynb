# %%
import requests
from bs4 import BeautifulSoup

# %%
req = requests.get("https://stats.espncricinfo.com/ci/engine/stats/index.html?class=11;result=1;result=2;result=3;result=4;spanmax1=31+Dec+2024;spanmin1=01+Jan+1970;spanval1=span;template=results;type=batting")

soup = BeautifulSoup(req.content, "html.parser")

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Access Denied
#   </title>
#  </head>
#  <body>
#   <h1>
#    Access Denied
#   </h1>
#   You don't have permission to access "http://stats.espncricinfo.com/ci/engine/stats/index.html?" on this server.
#   <p>
#    Reference #18.6e220f7a.1739773153.1f163ee7
#    <p>
#     https://errors.edgesuite.net/18.6e220f7a.1739773153.1f163ee7
#    </p>
#   </p>
#  </body>
# </html>
