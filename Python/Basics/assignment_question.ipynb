# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello World!")# Your code here
# Out:
# Hello World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
x = input("Enter your name : ")

print(x)
# Out:
# sahil

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
x = int(input("Enter the Number : "))

if x==0:
    print("It's a zero !!")

elif x>0:
    print("It's a possitive !!")

else:
    print("It's negative !!")
# Out:
# It's negative !!

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
a = int(input("Enter the no : "))
b = int(input("Enter the no : "))
c = int(input("Enter the no : "))

if ((a > b) and (a > c)):
    ##print(a)
    large = a
elif ((b > a) and (b > c)):
    ##print(b)
    large = b
else:
    ##print(c)
    large = c


print(f"The largest value : {large}")
# Out:
# The largest value : 3

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
def fact(n):
    if n==1 or n==0:
        return 1
    
    return n*fact(n-1)

x = int(input("Enter your no : "))

print(f"The factorial of {x} is : {fact(x)}")
# Out:
# The factorial of 5 is : 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
integer_value = 10
float_value = 3.200
string_value = "Sahil"
boolean_value = True

print(f"Integer Value : {integer_value} and type : {type(integer_value)}")
print(f"Float Value : {float_value} and type : {type(float_value)}")
print(f"String Value : {string_value} and type : {type(string_value)}")
print(f"Boolean Value : {boolean_value} and type : {type(boolean_value)}")
# Out:
# Integer Value : 10 and type : <class 'int'>
# Float Value : 3.2 and type : <class 'float'>
# String Value : Sahil and type : <class 'str'>
# Boolean Value : True and type : <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a = int(input("Enter the no : "))
b = int(input("Enter the no : "))

print(f"The Value of a is {a} and the value of b is {b}\n")

a ,b = b, a
print("After the swaping\n")

print(f"The Value of a is {a} and the value of b is {b}")
# Out:
# The Value of a is 10 and the value of b is 100
#
# After the swaping
#
# The Value of a is 100 and the value of b is 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
c = float(input("Enter the celsius : "))

fahrenheit = ((c*9)/5)+32

print(f"{c}°C is equal to {fahrenheit}°F")
# Out:
# 2.0°C is equal to 35.6°F

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
str1 = "Monkey D"
str2 = "Luffy"

con_str = str1 + " " +str2

print(con_str)
# Out:
# Monkey D Luffy

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# variable = 4000 ## give your input

# if isinstance(variable, int):
#     print(f"{variable} is an integer.")
# else:
#     print(f"{variable} is not an integer.")

# if isinstance(variable, str):
#     print(f"{variable} is a string.")
# else:
#     print(f"{variable} is not a string.")

# if isinstance(variable, float):
#     print(f"{variable} is a float.")
# else:
#     print(f"{variable} is not a float.")

# Take input from the user
user_input = input("Enter something: ")

try:
    val = int(user_input)
    print(f"{user_input} is an integer.")
except ValueError:
    try:
        val = float(user_input)
        print(f"{user_input} is a float.")
    except ValueError:
        print(f"{user_input} is a string.")
# Out:
# 10 is an integer.

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
x = float(input("Enter trhe number : "))
y = float(input("Enter trhe number : "))

print(f"The addition of {x} and {y} is : {x+y}")
print(f"The substraction of {x} and {y} is : {x-y}")
print(f"The multipication of {x} and {y} is : {x*y}")
print(f"The division of {x} and {y} is : {x/y}")
# Out:
# The addition of 4.0 and 2.0 is : 6.0
# The substraction of 4.0 and 2.0 is : 2.0
# The multipication of 4.0 and 2.0 is : 8.0
# The division of 4.0 and 2.0 is : 2.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
x = float(input("Enter trhe number : "))
y = float(input("Enter trhe number : "))

print(f"{x} == {y} : {x == y}") 
print(f"{x} > {y} : {x > y}")
print(f"{x} < {y} : {x < y}")
print(f"{x} != {y} : {x != y}")
# Out:
# 1.98 == 1.9879 : False
# 1.98 > 1.9879 : False
# 1.98 < 1.9879 : True
# 1.98 != 1.9879 : True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
x = True
y = False

print(f"True and False : {x and y}")
print(f"True or False : {x or y}")
print(f"Not True : {not x}")
# Out:
# True and False : False
# True or False : True
# Not True : False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
x = float(input("Enter the no : "))

print(f"The square of {x} is : {x**2}")
# Out:
# The square of 2.0 is : 4.0

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
x = int(input("Enter the no : "))

if ((x%2) == 0):
    print(f"The number {x} is Even number")

else:
    print(f"The number {x} is Odd number")
# Out:
# The number 9 is Odd number

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
x = int(input("Enter the no : "))
sum = ((x * (x + 1))//2)
print(f"The sum of N antural number is : {sum}")
# Out:
# The sum of N antural number is : 6

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = int(input("Enter th year : "))

if ((year % 4 == 0) and (year % 100 != 0)) or (year % 400 == 0):
    print(f"{year} is a Leap year")
else:
    print(f"{year} is a not Leap year")
# Out:
# 2023 is a not Leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
string_1 = input("Enter yor string : ")

print(f"Inputed string is {string_1}\n")

str_2 = string_1[::-1]

print(f"The reversed string is : {str_2}\n")
# Out:
# Inputed string is Robin
#
# The reversed string is : niboR

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
string_1 = input("Enter yor string : ")

if string_1 == string_1[::-1]:
    print(f"The {string_1} is palindrome")
else:
    print(f"The {string_1} is not palindrome")
# Out:
# The sahil is not palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# number = [int(x) for x in input("Enter the no seprated by space : ").split()]

# number.sort()

# print(number)

user_input = input("Enter the no seprated by space : ")

input_list = user_input.split()

numbers = []

for x in input_list:
    numbers.append(int(x))

numbers.sort()
print(numbers)
# Out:
# [1, 2, 3, 4, 5]
