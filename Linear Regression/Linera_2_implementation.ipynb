# %% [markdown]
# ### Linear Regression Implementation 2

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../DataSet/houseprice.csv')

# %%
df.head()
# Out:
#    AREA    PRICE
# 0  1360   327794
# 1  4272  1024734
# 2  3592   871245
# 3   966   232765
# 4  4926  1219080

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AREA    99 non-null     int64
#  1   PRICE   99 non-null     int64
# dtypes: int64(2)
# memory usage: 1.7 KB

# %%
df.describe()
# Out:
#               AREA         PRICE
# count    99.000000  9.900000e+01
# mean   2646.525253  6.412007e+05
# std    1261.520255  3.047400e+05
# min     534.000000  1.452950e+05
# 25%    1518.500000  3.683970e+05
# 50%    2778.000000  6.741680e+05
# 75%    3601.500000  8.683330e+05
# max    4993.000000  1.219080e+06

# %%
df.isnull().sum()
# Out:
# AREA     0
# PRICE    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(y='AREA', data=df)
# Out:
# <Axes: ylabel='AREA'>

# %%
sns.boxplot(y='PRICE', data=df)
# Out:
# <Axes: ylabel='PRICE'>

# %% [markdown]
# ##### It's mean data is clean

# %%
sns.pairplot(df)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['PRICE'], df['AREA'])
plt.xlabel('AREA')
plt.ylabel('PRICE')
plt.show()

# %%
df.corr()
# Out:
#           AREA    PRICE
# AREA   1.00000  0.99946
# PRICE  0.99946  1.00000

# %%
X = df[['AREA']]
X.head(5)
# Out:
#    AREA
# 0  1360
# 1  4272
# 2  3592
# 3   966
# 4  4926

# %%
y = df['PRICE']
y.head(5)
# Out:
# 0     327794
# 1    1024734
# 2     871245
# 3     232765
# 4    1219080
# Name: PRICE, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, test_size=0.25, random_state=42)

# %%
X_train.shape
# Out:
# (74, 1)

# %%
X_test.shape
# Out:
# (25, 1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-1.14976485],
#        [-0.29467576],
#        [ 2.00065   ],
#        [ 0.28635686],
#        [-0.63210264],
#        [ 1.47887283],
#        [ 0.95380369],
#        [-0.63868658],
#        [-1.01973205],
#        [ 1.15296784],
#        [ 0.42215061],
#        [-0.79587812],
#        [ 0.32256853],
#        [ 0.70855196],
#        [-1.27650567],
#        [ 0.69538408],
#        [ 0.72089684],
#        [ 1.16695871],
#        [-0.11855539],
#        [ 0.42379659],
#        [-1.3596279 ],
#        [ 0.56864325],
#        [ 0.84763767],
#        [-0.70699494],
#        [-1.52587236],
#        [-1.29790347],
#        [-1.29131954],
#        [ 0.01476938],
#        [-1.57442891],
#        [-0.01321236],
#        [ 0.92829092],
#        [-0.45104431],
#        [-1.18762249],
#        [ 0.60073995],
#        [ 0.46906117],
#        [-0.96541455],
#        [-0.8411427 ],
#        [-0.55967931],
#        [-0.07246782],
#        [-0.84525766],
#        [-1.04359883],
#        [-1.40406949],
#        [-0.05107001],
#        [-1.26827575],
#        [ 0.53654655],
#        [ 0.64271257],
#        [-0.44692935],
#        [-1.65343618],
#        [-1.51681945],
#        [ 1.4813418 ],
#        [-1.62874641],
#        [ 1.52002245],
#        [ 0.53243159],
#        [-1.54891615],
#        [ 1.06902262],
#        [ 0.19335872],
#        [ 0.26331308],
#        [-0.42388556],
#        [ 1.42290934],
#        [ 1.56364104],
#        [ 0.57934215],
#        [ 0.86327452],
#        [-0.19509368],
#        [ 0.33820538],
#        [ 0.56617427],
#        [ 1.51508449],
#        [ 0.87315043],
#        [ 1.24925795],
#        [ 0.00324748],
#        [ 1.85498035],
#        [-1.36950381],
#        [ 1.10441129],
#        [-0.38931988],
#        [-0.376975  ]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-8.62540503e-01],
#        [-1.69047084e-03],
#        [-8.35381755e-01],
#        [-7.90940166e-01],
#        [ 2.01628685e+00],
#        [ 8.69035470e-01],
#        [ 1.44430715e+00],
#        [ 4.68238180e-01],
#        [-1.04853678e+00],
#        [-9.73644475e-01],
#        [ 1.24514299e+00],
#        [ 4.32026515e-01],
#        [ 1.62207350e+00],
#        [ 7.91674186e-01],
#        [-4.65035182e-01],
#        [ 1.96114636e+00],
#        [-8.79000351e-01],
#        [ 3.20922543e-01],
#        [ 1.31838931e+00],
#        [ 1.55923692e-02],
#        [ 9.12654067e-01],
#        [ 1.60479066e+00],
#        [-9.58830612e-01],
#        [ 1.70684172e+00],
#        [-1.48307676e+00]])

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()

# %%
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Coffecient or slope : {linear.coef_}")
print(f"Intercept : {linear.intercept_}")
# Out:
# Coffecient or slope : [292632.37425431]
# Intercept : 615850.5810810811

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, linear.predict(X_train), color='red')

# %%
y_pred = linear.predict(X_test)

# %%
y_pred
# Out:
# array([ 363443.30565195,  615355.89458532,  371390.83474832,
#         384395.88236056, 1205881.38986698,  870158.49409918,
#        1038501.61041316,  752872.23137399,  309014.77305258,
#         330930.68662136,  980219.73037313,  742275.52591217,
#        1090521.80086212,  847520.07788529,  479766.23151698,
#        1189745.4974592 ,  358626.62135112,  709762.90688157,
#        1001653.97551182,  620413.41310119,  882922.70749638,
#        1085464.28234625,  335265.7024921 , 1115327.72501139,
#         181854.30751069])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)

# %%
print(f"Mean square error : {mse}")
print(f"Mean absolute error : {mae}")
print(f"Root mean square error : {rmse}")
# Out:
# Mean square error : 129412545.11224006
# Mean absolute error : 8721.603913702578
# Root mean square error : 11375.963480612974

# %%
score = r2_score(y_test, y_pred)

# %%
print(f"R2 Score : {score}")
# Out:
# R2 Score : 0.9987406566186048

# %%
import statsmodels.api as sm

# %%
model = sm.OLS(y_train, X_train).fit()

# %%
prediction = model.predict(X_test)
prediction
# Out:
# array([-2.52407275e+05, -4.94686496e+02, -2.44459746e+05, -2.31454699e+05,
#         5.90030809e+05,  2.54307913e+05,  4.22651029e+05,  1.37021650e+05,
#        -3.06835808e+05, -2.84919894e+05,  3.64369149e+05,  1.26424945e+05,
#         4.74671220e+05,  2.31669497e+05, -1.36084350e+05,  5.73894916e+05,
#        -2.57223960e+05,  9.39123258e+04,  3.85803394e+05,  4.56283202e+03,
#         2.67072126e+05,  4.69613701e+05, -2.80584879e+05,  4.99477144e+05,
#        -4.33996274e+05])

# %%
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  PRICE   R-squared (uncentered):                   0.184
# Model:                            OLS   Adj. R-squared (uncentered):              0.173
# Method:                 Least Squares   F-statistic:                              16.48
# Date:                Fri, 01 Aug 2025   Prob (F-statistic):                    0.000122
# Time:                        11:30:43   Log-Likelihood:                         -1091.5
# No. Observations:                  74   AIC:                                      2185.
# Df Residuals:                      73   BIC:                                      2187.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          2.926e+05   7.21e+04      4.059      0.000    1.49e+05    4.36e+05
# ==============================================================================
# Omnibus:                        2.415   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.299   Jarque-Bera (JB):                1.978
# Skew:                           0.399   Prob(JB):                        0.372
# Kurtosis:                       3.065   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
linear.predict(scaler.transform([[8459]]))
# Out:
# c:\Users\ASUS\Desktop\projects\Macchine_Learning\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([2040612.77920067])
